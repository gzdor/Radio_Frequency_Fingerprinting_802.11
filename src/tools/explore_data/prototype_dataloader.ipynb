# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
sys.path.append("..//Scripts")
from memory_mapper import load_parameters, SigMFDataMMapper
from sigmf_dataset import SigMFDataset, IQDataAugmenter, SigMFDataModule

# %%
sys.argv = ["", "../Parameters/memory_mapper.yml"]
parameters = load_parameters()

# %%
mmapper = SigMFDataMMapper(parameters)
dataset = SigMFDataset("training", mmapper, transform=IQDataAugmenter())

# %%
s0 = dataset[0][0]
s1 = dataset[0][0]
_, h_ax = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(6, 3))
h_ax[0].plot(s0[0,:])
h_ax[0].plot(s1[0,:])

h_ax[1].plot(s0[1,:])
h_ax[1].plot(s1[1,:])

# %%
s0 = dataset[0][0]
s1 = dataset[0][0]
_, h_ax = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(6, 3))
h_ax[0].plot(s0[0,:])
h_ax[0].plot(s1[0,:])

h_ax[1].plot(s0[1,:])
h_ax[1].plot(s1[1,:])

# %%
dm = SigMFDataModule(parameters)
dm.setup(stage="training")

# %%
dl = dm.train_dataloader()
batch = dl.__iter__().__next__()
